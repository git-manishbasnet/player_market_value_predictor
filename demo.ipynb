# %%
pip install pandas scikit-learn streamlit numpy matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.1 MB 10.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.4/9.1 MB 10.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.1/9.1 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 13.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/795.4 kB ? eta -:--:--
#    ---------------------------------------- 795.4/795.4 kB 9.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------------------------- -------------- 4.5/6.9 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 18.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/28.3 MB ? eta -:--:--
#    ------ --------------------------------- 4.5/28.3 MB 23.3 MB/s eta 0:00:02
#    ------------ --------------------------- 8.9/28.3 MB 19.9 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('player_value_50.csv')

# %%
df.head()
# Out:
#           PlayerName  Age  Matches  Goals  Assists  MarketValue_Million_EUR
# 0       Lionel Messi   34       30     25       21                      120
# 1  Cristiano Ronaldo   36       32     27        8                      115
# 2      Kylian Mbappe   22       28     20       10                      130
# 3     Erling Haaland   21       29     24        6                      125
# 4          Neymar Jr   29       25     18       14                      110

# %%
df.tail()
# Out:
#         PlayerName  Age  Matches  Goals  Assists  MarketValue_Million_EUR
# 46     Declan Rice   22       30      3        4                       70
# 47  Joshua Zirkzee   20       25      5        2                       50
# 48    Darwin Nunez   22       28     14        5                       80
# 49           Rodri   25       29      2        8                       75
# 50      Ruben Dias   24       30      1        3                       70

# %%
df.sample()
# Out:
#    PlayerName  Age  Matches  Goals  Assists  MarketValue_Million_EUR
# 17  Jan Oblak   28       32      0        1                       75

# %%
df.describe()
# Out:
#              Age    Matches      Goals    Assists  MarketValue_Million_EUR
# count  51.000000  51.000000  51.000000  51.000000                51.000000
# mean   27.372549  28.588235  10.843137   7.862745                84.803922
# std     4.293999   1.909727   8.417535   4.959918                18.329233
# min    20.000000  25.000000   0.000000   0.000000                50.000000
# 25%    23.500000  28.000000   4.000000   4.500000                70.000000
# 50%    28.000000  29.000000   9.000000   8.000000                80.000000
# 75%    30.000000  30.000000  18.000000  11.000000                95.000000
# max    36.000000  32.000000  28.000000  21.000000               130.000000

# %%
df.isnull().sum()
# Out:
# PlayerName                 0
# Age                        0
# Matches                    0
# Goals                      0
# Assists                    0
# MarketValue_Million_EUR    0
# dtype: int64

# %%
class_name=df['PlayerName'].unique()

# %%
print(class_name)
# Out:
# ['Lionel Messi' 'Cristiano Ronaldo' 'Kylian Mbappe' 'Erling Haaland'
#  'Neymar Jr' 'Mohamed Salah' 'Kevin De Bruyne' 'Robert Lewandowski'
#  'Harry Kane' 'Bruno Fernandes' 'Sadio Mane' 'Romelu Lukaku'
#  'Raheem Sterling' 'Son Heung-min' 'Trent Alexander-Arnold'
#  'Joshua Kimmich' 'Alisson Becker' 'Jan Oblak' 'Marc-André ter Stegen'
#  'Manuel Neuer' 'Virgil van Dijk' 'Sergio Ramos' 'Raphael Varane'
#  'Jadon Sancho' 'Phil Foden' 'Joao Felix' 'Frenkie de Jong' 'Paul Pogba'
#  'Luka Modric' 'Toni Kroos' 'Gianluigi Donnarumma' 'Ederson Moraes'
#  'Karim Benzema' 'Luis Suarez' 'Ciro Immobile' 'Raul Jimenez'
#  'Erik Lamela' 'Marco Reus' 'David Alaba' 'Thiago Alcantara'
#  'Angel Di Maria' 'Hakim Ziyech' 'Bernardo Silva' 'Kai Havertz'
#  'Mason Mount' 'Declan Rice' 'Joshua Zirkzee' 'Darwin Nunez' 'Rodri'
#  'Ruben Dias']

# %%
x=df[["Age","Matches","Goals","Assists"]]
y=df["MarketValue_Million_EUR"]
print(y[0])
# Out:
# 120

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train.head()
# Out:
#     Age  Matches  Goals  Assists
# 8    27       29     23        7
# 49   25       29      2        8
# 6    30       27     10       18
# 47   20       25      5        2
# 4    29       25     18       14

# %%
X_train.shape
# Out:
# (40, 4)

# %%
df.shape
# Out:
# (51, 6)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# %%
print(f"Mean Absolute Error: € {mae:.2f} Million")
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Absolute Error: € 5.74 Million
# Mean Squared Error: 57.81

# %%
comparison = pd.DataFrame({"Actual": y_test.values.flatten(), "Predicted": y_pred.flatten()})
print(comparison)
# Out:
#     Actual   Predicted
# 0       80   90.989014
# 1       75   71.855658
# 2       70   77.798330
# 3       95  103.197772
# 4       85   85.293417
# 5       70   74.701631
# 6       75   74.192102
# 7      105  103.154107
# 8      125  106.990454
# 9       75   71.284044
# 10     100  103.587930

# %%
print(df.columns)
# Out:
# Index(['PlayerName', 'Age', 'Matches', 'Goals', 'Assists',
#        'MarketValue_Million_EUR'],
#       dtype='object')

# %%
player_name = "Lionel Messi"  # Change to any player from dataset
player_stats = df[df['PlayerName'] == "Lionel Messi"][['Age','Matches','Goals','Assists']]
print(player_stats.shape)
# Out:
# (1, 4)

# %%
print(player_stats)
# Out:
# [[34 30 25 21]]

# %%
print(player_stats.shape)
# Out:
# (1, 4)

# %%
print(df[df['PlayerName'] == player_name])
# Out:
#      PlayerName  Age  Matches  Goals  Assists  MarketValue_Million_EUR
# 0  Lionel Messi   34       30     25       21                      120

# %%
prediction = model.predict(player_stats)
print(prediction.shape)
# Out:
# (1,)

# %%
df.columns
# Out:
# Index(['PlayerName', 'Age', 'Matches', 'Goals', 'Assists',
#        'MarketValue_Million_EUR'],
#       dtype='object')

# %%
df["PlayerName"].unique()
# Out:
# array(['Lionel Messi', 'Cristiano Ronaldo', 'Kylian Mbappe',
#        'Erling Haaland', 'Neymar Jr', 'Mohamed Salah', 'Kevin De Bruyne',
#        'Robert Lewandowski', 'Harry Kane', 'Bruno Fernandes',
#        'Sadio Mane', 'Romelu Lukaku', 'Raheem Sterling', 'Son Heung-min',
#        'Trent Alexander-Arnold', 'Joshua Kimmich', 'Alisson Becker',
#        'Jan Oblak', 'Marc-André ter Stegen', 'Manuel Neuer',
#        'Virgil van Dijk', 'Sergio Ramos', 'Raphael Varane',
#        'Jadon Sancho', 'Phil Foden', 'Joao Felix', 'Frenkie de Jong',
#        'Paul Pogba', 'Luka Modric', 'Toni Kroos', 'Gianluigi Donnarumma',
#        'Ederson Moraes', 'Karim Benzema', 'Luis Suarez', 'Ciro Immobile',
#        'Raul Jimenez', 'Erik Lamela', 'Marco Reus', 'David Alaba',
#        'Thiago Alcantara', 'Angel Di Maria', 'Hakim Ziyech',
#        'Bernardo Silva', 'Kai Havertz', 'Mason Mount', 'Declan Rice',
#        'Joshua Zirkzee', 'Darwin Nunez', 'Rodri', 'Ruben Dias'],
#       dtype=object)

# %%
player_stats.shape
# Out:
# (1, 4)

# %%
print(type(prediction))
# Out:
# <class 'numpy.ndarray'>

# %%
print(prediction.shape)
# Out:
# (1, 1)

# %%
print(prediction)
# Out:
# [115.7883559]

# %%
print(f"Predicted Market Value: € {prediction[0]:.2f} Million")
# Out:
# Predicted Market Value: € 115.79 Million
